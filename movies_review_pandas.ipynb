# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh-ml/MLBasics/blob/main/movies_review_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np


pd.options.display.max_columns=30
pd.options.display.float_format='{:.2f}'.format

# %%
df = pd.read_csv("/content/movies_complete.csv")

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# 3      Comedy|Drama|Romance                             NaN                en
# 4                    Comedy  Father of the Bride Collection                en
#
#    budget_musd  revenue_musd  \
# 0        30.00        373.55
# 1        65.00        262.80
# 2          nan           nan
# 3        16.00         81.45
# 4          nan         76.58
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
# 2                        Warner Bros.|Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4          Sandollar Productions|Touchstone Pictures
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America     5415.00          7.70       21.95    81.00
# 1  United States of America     2413.00          6.90       17.02   104.00
# 2  United States of America       92.00          6.50       11.71   101.00
# 3  United States of America       34.00          6.10        3.86   127.00
# 4  United States of America      173.00          5.70        8.39   106.00
#
#                                             overview  spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...           English
# 1  When siblings Judy and Peter discover an encha...  English|Français
# 2  A family wedding reignites the ancient feud be...           English
# 3  Cheated on, mistreated and stepped on, the wom...           English
# 4  Just when George Banks has recovered from his ...           English
#
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                                                 cast  cast_size  crew_size  \
# 0  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...         13        106
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...         26         16
# 2  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...          7          4
# 3  Whitney Houston|Angela Bassett|Loretta Devine|...         10         10
# 4  Steve Martin|Diane Keaton|Martin Short|Kimberl...         12          7
#
#           director
# 0    John Lasseter
# 1     Joe Johnston
# 2    Howard Deutch
# 3  Forest Whitaker
# 4    Charles Shyer

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# 50%          1.15    95.00      10.00       6.00
# 75%          3.77   107.00      15.00      12.00
# max        547.49  1256.00     313.00     435.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
# dtypes: float64(6), int64(3), object(13)
# memory usage: 7.5+ MB

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.hist(figsize=(20,12) , bins=100)
plt.show()

# %%
df.describe(include='object')
# Out:
#              title                 tagline release_date genres  \
# count        44691                   20284        44657  42586
# unique       41605                   20171        17225   4044
# top     Cinderella  Based on a true story.   2008-01-01  Drama
# freq            11                       7          133   4935
#
#        belongs_to_collection original_language       production_companies  \
# count                   4463             44681                      33356
# unique                  1691                89                      22537
# top          The Bowery Boys                en  Metro-Goldwyn-Mayer (MGM)
# freq                      29             31755                        741
#
#             production_countries                              overview  \
# count                      38835                                 43740
# unique                      2377                                 43715
# top     United States of America  Adaptation of the Jane Austen novel.
# freq                       17723                                     3
#
#        spoken_languages                                        poster_path  \
# count             41094                                              44467
# unique             1828                                              44456
# top             English  <img src='http://image.tmdb.org/t/p/w185//qW1o...
# freq              22189                                                  3
#
#                   cast   director
# count            42502      43960
# unique           42166      17349
# top     Georges Méliès  John Ford
# freq                24         66

# %% [markdown]
# The BEST and WORST movie

# %%
from IPython.display import HTML

# %%
df_best = df [['poster_path','title','budget_musd','revenue_musd','vote_count','vote_average','popularity']].copy()

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# 2                 Grumpier Old Men          nan           nan       92.00
# 3                Waiting to Exhale        16.00         81.45       34.00
# 4      Father of the Bride Part II          nan         76.58      173.00
# ...                            ...          ...           ...         ...
# 44686                       Subdue          nan           nan        1.00
# 44687          Century of Birthing          nan           nan        3.00
# 44688                     Betrayal          nan           nan        6.00
# 44689             Satan Triumphant          nan           nan        0.00
# 44690                     Queerama          nan           nan        0.00
#
#        vote_average  popularity
# 0              7.70       21.95
# 1              6.90       17.02
# 2              6.50       11.71
# 3              6.10        3.86
# 4              5.70        8.39
# ...             ...         ...
# 44686          4.00        0.07
# 44687          9.00        0.18
# 44688          3.80        0.90
# 44689           nan        0.00
# 44690           nan        0.16
#
# [44691 rows x 7 columns]

# %%
df_best['profit_musd'] = df.revenue_musd.sub(df.budget_musd)
df_best['return'] = df.revenue_musd.div(df.budget_musd)

# %%
df_best.head()
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_count  \
# 0                    Toy Story        30.00        373.55     5415.00
# 1                      Jumanji        65.00        262.80     2413.00
# 2             Grumpier Old Men          nan           nan       92.00
# 3            Waiting to Exhale        16.00         81.45       34.00
# 4  Father of the Bride Part II          nan         76.58      173.00
#
#    vote_average  popularity  profit_musd  return
# 0          7.70       21.95       343.55   12.45
# 1          6.90       17.02       197.80    4.04
# 2          6.50       11.71          nan     nan
# 3          6.10        3.86        65.45    5.09
# 4          5.70        8.39          nan     nan

# %% [markdown]
# **change column names for display purposes**

# %%
df_best.columns=['','Title','Budget','Revenue','Votes', 'Average Rating', 'Popularity','Profit','ROI']

# %%
df_best.set_index('Title', inplace=True)

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                nan
# Waiting to Exhale             16.00
# Father of the Bride Part II     nan

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.00</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_best.sort_values(by='Average Rating', ascending=False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# Satan Triumphant                            <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                                    <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                             Budget  Revenue  Votes  \
# Title
# Portrait of a Young Man in Three Movements     nan      nan   1.00
# Brave Revolutionary                            nan      nan   1.00
# Other Voices Other Rooms                       nan      nan   1.00
# The Lion of Thebes                             nan      nan   1.00
# Katt Williams: Priceless: Afterlife            nan      nan   2.00
# ...                                            ...      ...    ...
# Altar of Fire                                  nan      nan   0.00
# The Wonders of Aladdin                         nan      nan   0.00
# Deep Hearts                                    nan      nan   0.00
# Satan Triumphant                               nan      nan   0.00
# Queerama                                       nan      nan   0.00
#
#                                             Average Rating  Popularity  \
# Title
# Portrait of a Young Man in Three Movements           10.00        0.04
# Brave Revolutionary                                  10.00        0.32
# Other Voices Other Rooms                             10.00        0.04
# The Lion of Thebes                                   10.00        1.78
# Katt Williams: Priceless: Afterlife                  10.00        0.48
# ...                                                    ...         ...
# Altar of Fire                                          nan        0.00
# The Wonders of Aladdin                                 nan        0.09
# Deep Hearts                                            nan        0.01
# Satan Triumphant                                       nan        0.00
# Queerama                                               nan        0.16
#
#                                             Profit  ROI
# Title
# Portrait of a Young Man in Three Movements     nan  nan
# Brave Revolutionary                            nan  nan
# Other Voices Other Rooms                       nan  nan
# The Lion of Thebes                             nan  nan
# Katt Williams: Priceless: Afterlife            nan  nan
# ...                                            ...  ...
# Altar of Fire                                  nan  nan
# The Wonders of Aladdin                         nan  nan
# Deep Hearts                                    nan  nan
# Satan Triumphant                               nan  nan
# Queerama                                       nan  nan
#
# [44691 rows x 8 columns]

# %%
df_best.sort_values(by='ROI', ascending=False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                          Budget  Revenue  Votes  Average Rating  Popularity  \
# Title
# Less Than Zero             0.00    12.40  77.00            6.10        4.03
# Modern Times               0.00     8.50 881.00            8.10        8.16
# Welcome to Dongmakgol      0.00    33.58  49.00            7.70        4.22
# Aquí Entre Nos             0.00     2.76   3.00            6.00        0.23
# The Karate Kid, Part II    0.00   115.10 457.00            5.90        9.23
# ...                         ...      ...    ...             ...         ...
# Subdue                      nan      nan   1.00            4.00        0.07
# Century of Birthing         nan      nan   3.00            9.00        0.18
# Betrayal                    nan      nan   6.00            3.80        0.90
# Satan Triumphant            nan      nan   0.00             nan        0.00
# Queerama                    nan      nan   0.00             nan        0.16
#
#                          Profit         ROI
# Title
# Less Than Zero            12.40 12396383.00
# Modern Times               8.50  8500000.00
# Welcome to Dongmakgol     33.58  4197476.62
# Aquí Entre Nos             2.76  2755584.00
# The Karate Kid, Part II  115.10  1018619.28
# ...                         ...         ...
# Subdue                      nan         nan
# Century of Birthing         nan         nan
# Betrayal                    nan         nan
# Satan Triumphant            nan         nan
# Queerama                    nan         nan
#
# [44691 rows x 8 columns]

# %%
df_best.loc[df_best.Budget>5].sort_values(by='ROI', ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# The Exorcist                                    <img src='http://image.tmdb.org/t/p/w185//4ucL...
# Four Weddings and a Funeral                     <img src='http://image.tmdb.org/t/p/w185//qa72...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# Good Guys Go to Heaven, Bad Guys Go to Pattaya  <img src='http://image.tmdb.org/t/p/w185//cfVB...
# The Visitors: Bastille Day                      <img src='http://image.tmdb.org/t/p/w185//kBlm...
# House of the Long Shadows                       <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                                                 Budget  Revenue   Votes  \
# Title
# E.T. the Extra-Terrestrial                       10.50   792.97 3359.00
# Star Wars                                        11.00   775.40 6778.00
# Jaws                                              7.00   470.65 2628.00
# The Exorcist                                      8.00   441.31 2046.00
# Four Weddings and a Funeral                       6.00   254.70  654.00
# ...                                                ...      ...     ...
# The Blonde with Bare Breasts                      7.50      nan    3.00
# Detroit                                          34.00      nan   67.00
# Good Guys Go to Heaven, Bad Guys Go to Pattaya    5.40      nan  153.00
# The Visitors: Bastille Day                       25.87      nan  167.00
# House of the Long Shadows                         7.50      nan   18.00
#
#                                                 Average Rating  Popularity  \
# Title
# E.T. the Extra-Terrestrial                                7.30       19.36
# Star Wars                                                 8.10       42.15
# Jaws                                                      7.50       19.73
# The Exorcist                                              7.50       12.14
# Four Weddings and a Funeral                               6.60        8.99
# ...                                                        ...         ...
# The Blonde with Bare Breasts                              4.00        0.88
# Detroit                                                   7.30        9.80
# Good Guys Go to Heaven, Bad Guys Go to Pattaya            5.30        5.61
# The Visitors: Bastille Day                                4.00        7.29
# House of the Long Shadows                                 6.10        1.19
#
#                                                 Profit   ROI
# Title
# E.T. the Extra-Terrestrial                      782.47 75.52
# Star Wars                                       764.40 70.49
# Jaws                                            463.65 67.24
# The Exorcist                                    433.31 55.16
# Four Weddings and a Funeral                     248.70 42.45
# ...                                                ...   ...
# The Blonde with Bare Breasts                       nan   nan
# Detroit                                            nan   nan
# Good Guys Go to Heaven, Bad Guys Go to Pattaya     nan   nan
# The Visitors: Bastille Day                         nan   nan
# House of the Long Shadows                          nan   nan
#
# [5163 rows x 8 columns]

# %%
df_best.Budget.fillna(0, inplace=True)
df_best.ROI.fillna(0, inplace=True)

# %%
df_best.loc[df_best.Budget>5].sort_values(by='ROI', ascending=False)
# Out:
#                                                                                 \
# Title
# E.T. the Extra-Terrestrial   <img src='http://image.tmdb.org/t/p/w185//cBfk...
# Star Wars                    <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                         <img src='http://image.tmdb.org/t/p/w185//s2xc...
# The Exorcist                 <img src='http://image.tmdb.org/t/p/w185//4ucL...
# Four Weddings and a Funeral  <img src='http://image.tmdb.org/t/p/w185//qa72...
# ...                                                                        ...
# Robot Jox                    <img src='http://image.tmdb.org/t/p/w185//uzox...
# Beloved                      <img src='http://image.tmdb.org/t/p/w185//1T77...
# The Cutter                   <img src='http://image.tmdb.org/t/p/w185//8pwU...
# The Thing Called Love        <img src='http://image.tmdb.org/t/p/w185//3vKq...
# House of the Long Shadows    <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                              Budget  Revenue   Votes  Average Rating  \
# Title
# E.T. the Extra-Terrestrial    10.50   792.97 3359.00            7.30
# Star Wars                     11.00   775.40 6778.00            8.10
# Jaws                           7.00   470.65 2628.00            7.50
# The Exorcist                   8.00   441.31 2046.00            7.50
# Four Weddings and a Funeral    6.00   254.70  654.00            6.60
# ...                             ...      ...     ...             ...
# Robot Jox                     10.00      nan   32.00            5.30
# Beloved                        8.98      nan   24.00            6.70
# The Cutter                     6.00      nan   14.00            4.10
# The Thing Called Love         14.00      nan   41.00            6.50
# House of the Long Shadows      7.50      nan   18.00            6.10
#
#                              Popularity  Profit   ROI
# Title
# E.T. the Extra-Terrestrial        19.36  782.47 75.52
# Star Wars                         42.15  764.40 70.49
# Jaws                              19.73  463.65 67.24
# The Exorcist                      12.14  433.31 55.16
# Four Weddings and a Funeral        8.99  248.70 42.45
# ...                                 ...     ...   ...
# Robot Jox                          3.31     nan  0.00
# Beloved                            2.02     nan  0.00
# The Cutter                         4.42     nan  0.00
# The Thing Called Love              2.92     nan  0.00
# House of the Long Shadows          1.19     nan  0.00
#
# [5163 rows x 8 columns]

# %%
def best_worst(n, by , ascending=False, min_bud=0, min_votes=0):
  df2= df_best.loc[(df_best.Budget >= min_bud) & 
                   (df_best.Votes >= min_votes),
                   ["", by]].sort_values(by = by, ascending=ascending).head(n).copy()
  return HTML(df2.to_html(escape=False))

# %% [markdown]
# **Best Movies/worst movies**

# %%
best_worst(n= 5, by ="Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.56</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1513.53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Best Movies By Budget**

# %%
best_worst(n= 5, by ="Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.00</td>
#     </tr>
#     <tr>
#       <th>Transformers: The Last Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg' style='height:100px;'></td>
#       <td>260.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Movies lowest profit**

# %%
best_worst(n= 5, by ="Profit", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jfIpMh79fGRqYJ6PwZLCntzgxlF.jpg' style='height:100px;'></td>
#       <td>-107.45</td>
#     </tr>
#     <tr>
#       <th>The 13th Warrior</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7pyhR5K1iv67daYw0DfsmsersKA.jpg' style='height:100px;'></td>
#       <td>-98.30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Movies Top ROI**

# %%
best_worst(n= 5, by ="ROI", min_bud=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>E.T. the Extra-Terrestrial</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'></td>
#       <td>75.52</td>
#     </tr>
#     <tr>
#       <th>My Big Fat Greek Wedding</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'></td>
#       <td>73.75</td>
#     </tr>
#     <tr>
#       <th>Star Wars</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'></td>
#       <td>70.49</td>
#     </tr>
#     <tr>
#       <th>Jaws</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'></td>
#       <td>67.24</td>
#     </tr>
#     <tr>
#       <th>Crocodile Dundee</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'></td>
#       <td>65.64</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Movies lowest ROI**

# %%
best_worst(n= 5, by ="ROI", ascending=False, min_bud=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>13.50</td>
#     </tr>
#     <tr>
#       <th>Despicable Me 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xL6t0Fo38DjiiuNLVSj58xJWNJy.jpg' style='height:100px;'></td>
#       <td>12.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
#top 5 by Rating
best_worst(n= 5, by ="Average Rating", min_votes=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>As I Was Moving Ahead Occasionally I Saw Brief Glimpses of Beauty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//k0I65rky3t2HiVciCm1MquV1kSb.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>The Civil War</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//r4sWAokhRr5gYgl5GjzQ8XXCXwI.jpg' style='height:100px;'></td>
#       <td>9.20</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Cosmos</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mYrnDinyVDhWatHYSwADTTYqoMG.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_worst(n= 5, by ="Average Rating", min_votes=10 , min_bud=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Human</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vdZgH8cr73DJTLwvyzFpmm9l3xV.jpg' style='height:100px;'></td>
#       <td>8.60</td>
#     </tr>
#     <tr>
#       <th>The Godfather</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iVZ3JAcAjmguGPnRNfWFOtLHOuY.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>The Shawshank Redemption</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5KCVkau1HEl7ZzfPsKAPM0sMiKc.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>Fight Club</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bptfVGEQuv6vDTIMVCHjJ9Dz8PX.jpg' style='height:100px;'></td>
#       <td>8.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
#most popular
best_worst(n= 5, by ="Votes", min_votes=10 , min_bud=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>12000.00</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>11444.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Find Your Next Movie

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genres= df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor=df.cast.str.contains('Bruce Willis')

# %%
df.loc[mask_actor & mask_genres, ['title', 'vote_average']].sort_values(by='vote_average', ascending=False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
bruce=df.loc[mask_actor & mask_genres , ["title", "poster_path", "vote_average"]].sort_values(by='vote_average', ascending=False)

# %%
HTML(bruce.to_html(
    escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//v3Z0Hbl0oe57njrrIPh0fJPFoo.jpg' style='height:100px;'></td>
#       <td>5.90</td>
#     </tr>
#     <tr>
#       <th>20333</th>
#       <td>G.I. Joe: Retaliation</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//3rWIZMzTKcCtV0eHJ70Z4Ru659f.jpg' style='height:100px;'></td>
#       <td>5.40</td>
#     </tr>
#     <tr>
#       <th>27619</th>
#       <td>Vice</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//nPqNoQ55RIrmmo9mpqg1jE3ENza.jpg' style='height:100px;'></td>
#       <td>4.10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Movies by Actor and Director**

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_actor = df.cast.str.contains("Uma Thurman")
mask_director=df.director=="Quentin Tarantino"

# %%
quentin = df.loc[mask_actor & mask_director, ['title','poster_path','runtime']].sort_values(by='runtime').set_index('title')

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***Most Successful movies By Pixar Studio between 2010 to 2015*

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
mask_studio= df.production_companies.str.contains("Pixar").fillna(False)

# %%
df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 44686           NaN
# 44687    2011-11-17
# 44688    2003-08-01
# 44689    1917-10-21
# 44690    2017-06-09
# Name: release_date, Length: 44691, dtype: object

# %%
mask_time= df.release_date.between("2010-01-01","2015-12-31")

# %%
pixar = df.loc[mask_time & mask_studio, ['title','poster_path','revenue_musd', 'release_date']].sort_values(by='revenue_musd').set_index('title')

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Good Dinosaur</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8RSkxOO80btfKjyiC5ZiTaCHIT8.jpg' style='height:100px;'></td>
#       <td>331.93</td>
#       <td>2015-11-14</td>
#     </tr>
#     <tr>
#       <th>Brave</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8l0pzWBrStFtbZiqeu0cGhxGKkT.jpg' style='height:100px;'></td>
#       <td>538.98</td>
#       <td>2012-06-21</td>
#     </tr>
#     <tr>
#       <th>Cars 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'></td>
#       <td>559.85</td>
#       <td>2011-06-11</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Day & Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2010-06-17</td>
#     </tr>
#     <tr>
#       <th>The Blue Umbrella</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iSWV7ra8HJ3gYnZFMMrPe8CBbrv.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2013-02-12</td>
#     </tr>
#     <tr>
#       <th>Toy Story of Terror!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aNDrMDZYmcoMlJa6K3VicYeAgt1.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2013-10-15</td>
#     </tr>
#     <tr>
#       <th>La luna</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iS6DB1hIRJHQPs9wWXvIzdnp7oD.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2011-01-01</td>
#     </tr>
#     <tr>
#       <th>Hawaiian Vacation</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tByW10AkjWG0DtZwN2E2trT88DD.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2011-06-16</td>
#     </tr>
#     <tr>
#       <th>Small Fry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//z096FtMoUZxf9kqzSj39YE6psuD.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2011-11-23</td>
#     </tr>
#     <tr>
#       <th>Partysaurus Rex</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ylj9TnXrTgiETysgBoSb8UQwEUc.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2012-09-14</td>
#     </tr>
#     <tr>
#       <th>The Legend of Mor'du</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8FKR6880g0JRiblbTQEijGlq3Qj.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2012-01-01</td>
#     </tr>
#     <tr>
#       <th>Toy Story That Time Forgot</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jqQPN3X3aV5VmpTiEEASt36nlfi.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2014-12-02</td>
#     </tr>
#     <tr>
#       <th>Lava</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//blZSkXNN4CzRBxdxXnz3YpUjnJp.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2015-06-21</td>
#     </tr>
#     <tr>
#       <th>Sanjay's Super Team</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mShcGzOctlq6zs33UdrCdAwZMGq.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2015-11-25</td>
#     </tr>
#     <tr>
#       <th>Air Mater</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jDwglSvFNBfWJNiyxD41CUcUic1.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2011-08-04</td>
#     </tr>
#     <tr>
#       <th>Riley's First Date?</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pyry5DuBCUiX02OtXRpPsjJ1r0L.jpg' style='height:100px;'></td>
#       <td>nan</td>
#       <td>2015-11-03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Action or Thriller Movies with English original language and minimum rating 7.5:**

# %%
mask_genre = df.genres.str.contains('Action') |  df.genres.str.contains('Thriller')

# %%
mask_lan = df.original_language =='en'
mask_vote_av = df.vote_average >= 7.5
mask_vote_co = df.vote_count >=10

# %%
next_movie =  df.loc[mask_lan & mask_vote_av & mask_vote_co, 
                     ['title','poster_path','genres', 'vote_average', 'vote_count','release_date']].sort_values(by ='release_date', 
                                  ascending=False).set_index('title').head(20)

# %%
HTML(next_movie.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ingrid Goes West</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3LEyW11onDltXHo0L1X23j9Nnvg.jpg' style='height:100px;'></td>
#       <td>Drama|Comedy</td>
#       <td>7.60</td>
#       <td>18.00</td>
#       <td>2017-08-11</td>
#     </tr>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
#       <td>2017-07-19</td>
#     </tr>
#     <tr>
#       <th>The Big Sick</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qquEFkFbQX1i8Bal260EgGCnZ0f.jpg' style='height:100px;'></td>
#       <td>Comedy|Drama|Romance</td>
#       <td>7.70</td>
#       <td>249.00</td>
#       <td>2017-06-23</td>
#     </tr>
#     <tr>
#       <th>Lou</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//zAQmOmQPWyvU34B3gcK163P4jmH.jpg' style='height:100px;'></td>
#       <td>Animation</td>
#       <td>8.50</td>
#       <td>17.00</td>
#       <td>2017-06-16</td>
#     </tr>
#     <tr>
#       <th>The Book of Henry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//suLFg4UjvM5BoDipg2Wu3gZ802T.jpg' style='height:100px;'></td>
#       <td>Thriller|Drama|Crime</td>
#       <td>7.60</td>
#       <td>84.00</td>
#       <td>2017-06-16</td>
#     </tr>
#     <tr>
#       <th>In a Heartbeat</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wJUJROdLOtOzMixkjkx1aaZGSLl.jpg' style='height:100px;'></td>
#       <td>Family|Animation|Romance|Comedy</td>
#       <td>8.30</td>
#       <td>146.00</td>
#       <td>2017-06-01</td>
#     </tr>
#     <tr>
#       <th>Sarah Silverman: A Speck of Dust</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mLkMiOtmobwk8f85oJUK7ZqcaD9.jpg' style='height:100px;'></td>
#       <td>Comedy</td>
#       <td>7.70</td>
#       <td>11.00</td>
#       <td>2017-05-30</td>
#     </tr>
#     <tr>
#       <th>McLaren</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//yRWIvyWNgsuPSHEVIMbS9aDY280.jpg' style='height:100px;'></td>
#       <td>Documentary</td>
#       <td>8.00</td>
#       <td>13.00</td>
#       <td>2017-05-25</td>
#     </tr>
#     <tr>
#       <th>Hasan Minhaj: Homecoming King</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qnd3bxP6k1Wbk6Gl76avB9GaO0U.jpg' style='height:100px;'></td>
#       <td>Comedy</td>
#       <td>8.10</td>
#       <td>22.00</td>
#       <td>2017-05-23</td>
#     </tr>
#     <tr>
#       <th>The Keepers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ltmLBAM6Yj7aBf4hhtdr3CCl2eM.jpg' style='height:100px;'></td>
#       <td>Crime|Documentary|Drama</td>
#       <td>7.90</td>
#       <td>16.00</td>
#       <td>2017-05-19</td>
#     </tr>
#     <tr>
#       <th>Okja</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pHlRr2MfjK77VIIAO7p0R4jhsJI.jpg' style='height:100px;'></td>
#       <td>Adventure|Drama|Fantasy|Science Fiction</td>
#       <td>7.70</td>
#       <td>795.00</td>
#       <td>2017-05-19</td>
#     </tr>
#     <tr>
#       <th>Batman & Bill</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gc1oyq0K8TdtFTXmYV03v536HsI.jpg' style='height:100px;'></td>
#       <td>Documentary</td>
#       <td>7.70</td>
#       <td>11.00</td>
#       <td>2017-05-06</td>
#     </tr>
#     <tr>
#       <th>I Am Heath Ledger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96ScsrVx2tAlWuiZYgqwcuGYdYK.jpg' style='height:100px;'></td>
#       <td>Documentary</td>
#       <td>7.50</td>
#       <td>26.00</td>
#       <td>2017-04-23</td>
#     </tr>
#     <tr>
#       <th>Guardians of the Galaxy Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg' style='height:100px;'></td>
#       <td>Action|Adventure|Comedy|Science Fiction</td>
#       <td>7.60</td>
#       <td>4858.00</td>
#       <td>2017-04-19</td>
#     </tr>
#     <tr>
#       <th>Maudie</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wu9RPdV0uEemFEewJQ6fWwJ9ZcU.jpg' style='height:100px;'></td>
#       <td>Drama|History|Romance</td>
#       <td>7.60</td>
#       <td>20.00</td>
#       <td>2017-04-14</td>
#     </tr>
#     <tr>
#       <th>Gifted</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9Ts7Vc4wLlpI9oox9mkVUE1tBHy.jpg' style='height:100px;'></td>
#       <td>Drama</td>
#       <td>7.70</td>
#       <td>549.00</td>
#       <td>2017-04-12</td>
#     </tr>
#     <tr>
#       <th>Louis C.K. 2017</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nzwPnI49vJJ8Dw4SB7BL9nJ0USX.jpg' style='height:100px;'></td>
#       <td>Comedy</td>
#       <td>7.50</td>
#       <td>72.00</td>
#       <td>2017-04-04</td>
#     </tr>
#     <tr>
#       <th>Red Nose Day Actually</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//m7gBvNIXFwvuZKXd0CdbX9vwj5B.jpg' style='height:100px;'></td>
#       <td>TV Movie|Comedy|Romance</td>
#       <td>7.70</td>
#       <td>29.00</td>
#       <td>2017-03-24</td>
#     </tr>
#     <tr>
#       <th>Dave Chappelle: The Age of Spin</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lFGP9COk4X3sBqrkUpbQ78GdnZm.jpg' style='height:100px;'></td>
#       <td>Comedy</td>
#       <td>7.60</td>
#       <td>43.00</td>
#       <td>2017-03-21</td>
#     </tr>
#   </tbody>
# </table>

# %%
#WordCloud
from wordcloud import WordCloud

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44686         Rising and falling between a man and woman          NaN
# 44687                                                NaN   2011-11-17
# 44688                             A deadly game of wits.   2003-08-01
# 44689                                                NaN   1917-10-21
# 44690                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44686              Drama|Family                             NaN
# 44687                     Drama                             NaN
# 44688     Action|Drama|Thriller                             NaN
# 44689                       NaN                             NaN
# 44690                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en        30.00        373.55
# 1                    en        65.00        262.80
# 2                    en          nan           nan
# 3                    en        16.00         81.45
# 4                    en          nan         76.58
# ...                 ...          ...           ...
# 44686                fa          nan           nan
# 44687                tl          nan           nan
# 44688                en          nan           nan
# 44689                en          nan           nan
# 44690                en          nan           nan
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44686                                                NaN
# 44687                                        Sine Olivia
# 44688                            American World Pictures
# 44689                                          Yermoliev
# 44690                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America     5415.00          7.70       21.95
# 1      United States of America     2413.00          6.90       17.02
# 2      United States of America       92.00          6.50       11.71
# 3      United States of America       34.00          6.10        3.86
# 4      United States of America      173.00          5.70        8.39
# ...                         ...         ...           ...         ...
# 44686                      Iran        1.00          4.00        0.07
# 44687               Philippines        3.00          9.00        0.18
# 44688  United States of America        6.00          3.80        0.90
# 44689                    Russia        0.00           nan        0.00
# 44690            United Kingdom        0.00           nan        0.16
#
#        runtime                                           overview  \
# 0        81.00  Led by Woody, Andy's toys live happily in his ...
# 1       104.00  When siblings Judy and Peter discover an encha...
# 2       101.00  A family wedding reignites the ancient feud be...
# 3       127.00  Cheated on, mistreated and stepped on, the wom...
# 4       106.00  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44686    90.00        Rising and falling between a man and woman.
# 44687   360.00  An artist struggles to finish his work while a...
# 44688    90.00  When one of her hits goes wrong, a professiona...
# 44689    87.00  In a small town live two brothers, one a minis...
# 44690    75.00  50 years after decriminalisation of homosexual...
#
#        spoken_languages                                        poster_path  \
# 0               English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2               English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3               English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4               English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                 ...                                                ...
# 44686             فارسی  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687               NaN  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688           English  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689               NaN  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690           English  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                     cast  cast_size  \
# 0      Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...         13
# 1      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...         26
# 2      Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...          7
# 3      Whitney Houston|Angela Bassett|Loretta Devine|...         10
# 4      Steve Martin|Diane Keaton|Martin Short|Kimberl...         12
# ...                                                  ...        ...
# 44686            Leila Hatami|Kourosh Tahami|Elham Korda          3
# 44687  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...         11
# 44688  Erika Eleniak|Adam Baldwin|Julie du Page|James...         15
# 44689  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...          5
# 44690                                                NaN          0
#
#        crew_size          director
# 0            106     John Lasseter
# 1             16      Joe Johnston
# 2              4     Howard Deutch
# 3             10   Forest Whitaker
# 4              7     Charles Shyer
# ...          ...               ...
# 44686          9  Hamid Nematollah
# 44687          6          Lav Diaz
# 44688          5    Mark L. Lester
# 44689          2  Yakov Protazanov
# 44690          1     Daisy Asquith
#
# [44691 rows x 22 columns]

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline= df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
''.join(title)
# Out:
# 'Toy StoryJumanjiGrumpier Old MenWaiting to ExhaleFather of the Bride Part IIHeatSabrinaTom and HuckSudden DeathGoldenEyeThe American PresidentDracula: Dead and Loving ItBaltoNixonCutthroat IslandCasinoSense and SensibilityFour RoomsAce Ventura: When Nature CallsMoney TrainGet ShortyCopycatAssassinsPowderLeaving Las VegasOthelloNow and ThenPersuasionThe City of Lost ChildrenShanghai TriadDangerous MindsTwelve MonkeysWings of CourageBabeCarringtonDead Man WalkingAcross the Sea of TimeIt Takes TwoCluelessCry, the Beloved CountryRichard IIIDead PresidentsRestorationMortal KombatTo Die ForHow To Make An American QuiltSe7enPocahontasWhen Night Is FallingThe Usual SuspectsGuardian AngelMighty AphroditeLamericaThe Big GreenGeorgiaKids of the Round TableHome for the HolidaysThe PostmanThe ConfessionalThe Indian in the CupboardEye for an EyeMr. Holland\'s OpusDon\'t Be a Menace to South Central While Drinking Your Juice in the HoodTwo If by SeaBio-DomeLawnmower Man 2: Beyond CyberspaceTwo BitsFrench TwistFridayFrom Dusk Till DawnFair GameKicking and ScreamingLes MiserablesBed of RosesBig BullyScreamersNico IconThe Crossing GuardThe JurorThe White BalloonThings to Do in Denver When You\'re DeadAntonia\'s LineOnce Upon a Time... When We Were ColoredLast Summer in the HamptonsAngels and InsectsWhite SquallDunston Checks InBlack SheepNick of TimeThe Journey of August KingMary ReillyVampire in BrooklynBeautiful GirlsBroken ArrowA Midwinter\'s TaleLa HaineShoppingHeidi Fleiss: Hollywood MadamCity HallBottle RocketMr. WrongUnforgettableHappy GilmoreThe Bridges of Madison CountyNobody Loves MeMuppet Treasure IslandCatwalkHeadless Body in Topless BarBraveheartTaxi DriverRumble in the BronxBefore and AfterMargaret\'s MuseumHappiness Is in the FieldAnne Frank RememberedThe Young Poisoner\'s HandbookIf Lucy FellSteal Big Steal LittleRace the SunThe Boys of St. VincentBoomerangChungking ExpressThe Star MakerFlirting with DisasterThe Neverending Story III: Escape from FantasiaThe Silences of the PalaceJupiter\'s WifePie in the SkyAngelaFrankie StarlightJadeNueba YolSonic OutlawsDown PeriscopeFrom the Journals of Jean SebergMan of the YearThe Neon BibleTargetUp Close & PersonalThe BirdcageVirgin MaryThe Brothers McMullenBad BoysThe Amazing Panda AdventureThe Basketball DiariesAn Awfully Big AdventureAmateurApollo 13Rob RoyThe AddictionBatman ForeverBelle de JourBeyond RangoonBlue in the FaceCanadian BaconCasperClockersCongoCrimson TideCrumbDesperadoDevil in a Blue DressDie Hard: With a VengeanceThe Doom GenerationFeast of JulyFirst KnightFree Willy 2 - The Adventure HomeHackersJeffreyJohnny MnemonicJudge DreddJury DutyKidsLiving in OblivionLord of IllusionsLove & Human RemainsMad LoveMallratsMighty Morphin Power Rangers: The MovieMoonlight and ValentinoMute WitnessNadjaThe NetNine MonthsParty GirlThe ProphecyRecklessSafeThe Scarlet LetterShowgirlsSmokeSomething to Talk AboutSpeciesThe Stars Fell on HenriettaStrange DaysThe Umbrellas of CherbourgThe Tie That BindsThree WishesTotal EclipseTo Wong Foo, Thanks for Everything! Julie NewmarUnder Siege 2: Dark TerritoryUnstrung HeroesUnzippedA Walk in the CloudsWaterworldWhite Man\'s BurdenWild BillThe Browning VersionBushwhackedBurnt by the SunBefore the RainBefore SunriseBilly MadisonThe BabysitterBoys on the SideThe CureCastle FreakCircle of FriendsClerksDon Juan DeMarcoDisclosureDream ManDrop ZoneDestiny Turns on the RadioDeath and the MaidenDolores ClaiborneDumb and DumberEat Drink Man WomanExoticaExit to EdenEd WoodFrench KissForget ParisFar from Home: The Adventures of Yellow DogA Goofy MovieHideawayFlukeFarinelliGordyGumby: The MovieThe Glass ShieldHoop DreamsHeavenly CreaturesHouseguestImmortal BelovedHeavyweightsThe HuntedI.Q.Interview with the VampireJefferson in ParisThe Jerky BoysJuniorJust CauseA Kid in King Arthur\'s CourtKiss of DeathStar WarsLittle WomenA Little PrincessLadybird LadybirdL\'EnferLike Water for ChocolateLegends of the FallMajor PayneLittle OdessaMi Vida LocaLove AffairLosing  ...

# %%
title_corpus = ''.join(title)
overview_corpus=''.join(overview)
tagline_corpus=''.join(tagline)

# %%
tagline_corpus
# Out:
# 'Roll the dice and unleash the excitement!Still Yelling. Still Fighting. Still Ready for Love.Friends are the people who let you be yourself... and never let you forget it.Just When His World Is Back To Normal... He\'s In For The Surprise Of His Life!A Los Angeles Crime SagaYou are cordially invited to the most surprising merger of the year.The Original Bad Boys.Terror goes into overtime.No limits. No fears. No substitutes.Why can\'t the most powerful man in the world have the one thing he wants most?Part Dog. Part Wolf. All Hero.Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation.The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime!No one stays at the top forever.Lose your heart and come to your senses.Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who\'s in for the wildest New year\'s Eve of his life.New animals. New adventures. Same hair.Get on, or GET OUT THE WAY!The mob is tough, but it’s nothing like show business.One man is copying the most notorious killers in history one at a time. Together, two women must stop him from killing again. Or they\'re next.In the shadows of life, In the business of death, One man found a reason to live...An extraordinary encounter with another human being.I Love You... The Way You Are.Envy, greed, jealousy and love.In every woman there is the girl she left behind.Where happily ever after is just a dream.In 1930\'s Shanghai violence was not the problem. It was the solution.She broke the rules... and changed their lives.The future is history.A little pig goes a long way.A Love so Unusual it has to be TrueTwo identical strangers. Two different worlds. One perfect match.Sex. Clothes. Popularity. Is there a problem here?I can smile, and murder while I smileIn this daring heist, the only color that counts is greenNothing In This World Has Prepared You For This.All she wanted was a little attention.There\'s beauty in the patterns of life.Seven deadly sins. Seven ways to die.An American legend comes to life.Five Criminals. One Line Up. No Coincidence.She\'s no angel of mercy.The biggest kick of the year!The toughest act to follow was their dreams.We\'ll do it every year..until we get it rightWhat do you do when justice fails?Of All the Lives He Changed, the One That Changed the Most Was His Own.Finally, the movie that proves that Justice isn\'t always Poetic, Jungle Fever isn\'t always pretty, and Higher Learning can be a waste of time.A new comedy about love, laughter, and larcenyBud and Doyle are here to save the world. But who\'s gonna save the world from Bud and Doyle?God made him simple. Science made him a god. Now, he wants revenge.You\'re never too old to believe in a dream. Or too young to make one come true!A lot can go down between thursday and saturday...One night is all that stands between them and freedom. But it\'s going to be a hell of a night.He\'s a cop on the edge. She\'s a woman with a dangerous secret. And now they\'re both...Anxiety loves company.In a time of chaos, in a world of change, he was moved by a book he could not read to become a hero he never imagined.He gave her flowers. She gave him a chance.A comedy for the kid in all of us.The last scream you hear will be your own....some lives cross, others collide.There is no defense.Protect. Love. Honor. Avenge.A motion picture that celebrates everything you love about life.An elegant seduction. An erotic deception. A stunning revelation.He\'s about to turn a Five Star Hotel into a three ring circus.There\'s one in every family.The untold story of Jekyll and HydeA comic tale of horror and seduction.Good times never seemed so good,Prepare to Go Ballistic.The drama. The passion. The intrigue... And the rehearsals haven\'t even started.Three Young Friends... One Last Chance.No one leaves without paying...   It started with a shootout on a rainswept street and ended in  ...

# %%
title_wordcloud= WordCloud(background_color='white', height=2000, width=3000, max_words=200).generate(title_corpus)

title_wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wordcloud= WordCloud(background_color='white', height=2000, width=2000, max_words=200).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
overview_wordcloud= WordCloud(background_color='white', height=2000, width=3000, max_words=200).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# `ARE FRANCHISE MORE SUCCESSFUL ? `

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df['franchise'] = df.belongs_to_collection.notna()

# %%
df.franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: franchise, Length: 44691, dtype: bool

# %%
df.franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: franchise, dtype: int64

# %%
next_movie

# %% [markdown]
# **Franchise Vs Stand ALone**

# %%
df.groupby("franchise").revenue_musd.mean()
# Out:
# franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %%
df['ROI'] = df.revenue_musd.div(df.budget_musd)
df.groupby('franchise').ROI.median()
# Out:
# franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %%
df.groupby('franchise').popularity.mean()
# Out:
# franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %%
df.groupby('franchise').vote_average.mean()
# Out:
# franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
#aggregate
df.groupby('franchise').agg({'budget_musd':'mean', 
                             'revenue_musd':'mean', 'vote_average':'mean',
                             'popularity':'mean', 'ROI':'median', 'vote_count':'mean'})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# franchise
# False           78.29
# True           412.39

# %% [markdown]
# **Most Successful Franchise**

# %%
franchise = df.groupby('belongs_to_collection').agg({'title':'count', 'budget_musd':['mean','sum'], 
                             'revenue_musd':['mean','sum'], 'vote_average':'mean',
                             'popularity':'mean', 'ROI':'median', 'vote_count':'mean'})

# %%
franchise
# Out:
#                                      budget_musd        revenue_musd         \
#                                             mean    sum         mean    sum
# belongs_to_collection
# ... Has Fallen Collection                  65.00 130.00       183.39 366.78
# 00 Schneider Filmreihe                       nan   0.00          nan   0.00
# 08/15 Collection                             nan   0.00          nan   0.00
# 100 Girls Collection                         nan   0.00          nan   0.00
# 101 Dalmatians (Animated) Collection        4.00   4.00       215.88 215.88
# ...                                          ...    ...          ...    ...
# Сказки Чуковского                            nan   0.00          nan   0.00
# Чебурашка и крокодил Гена                    nan   0.00          nan   0.00
# Что Творят мужчины! (Коллекция)             2.00   2.00          nan   0.00
# 男はつらいよ シリーズ                                  nan   0.00          nan   0.00
# 식객 시리즈                                       nan   0.00          nan   0.00
#
#                                      vote_average popularity    ROI vote_count
#                                              mean       mean median       mean
# belongs_to_collection
# ... Has Fallen Collection                    6.00      13.01   2.86    2333.00
# 00 Schneider Filmreihe                       6.50       1.93    nan      16.00
# 08/15 Collection                             5.90       0.63    nan       4.00
# 100 Girls Collection                         5.15       3.08    nan      64.00
# 101 Dalmatians (Animated) Collection         6.25      13.06  53.97     937.00
# ...                                           ...        ...    ...        ...
# Сказки Чуковского                            3.00       0.73    nan       3.00
# Чебурашка и крокодил Гена                    6.70       0.88    nan       7.00
# Что Творят мужчины! (Коллекция)              3.15       1.30    nan       5.50
# 男はつらいよ シリーズ                                  7.00       0.04    nan       0.67
# 식객 시리즈                                       4.95       0.16    nan       3.50
#
# [1691 rows x 8 columns]

# %%
franchise.nlargest(20, ('title','count'))
# Out:
#                                        title budget_musd         revenue_musd  \
#                                        count        mean     sum         mean
# belongs_to_collection
# The Bowery Boys                           29         nan    0.00          nan
# Totò Collection                           27         nan    0.00          nan
# James Bond Collection                     26       59.22 1539.65       273.35
# Zatôichi: The Blind Swordsman             26         nan    0.00          nan
# The Carry On Collection                   25         nan    0.00          nan
# Charlie Chan (Sidney Toler) Collection    21         nan    0.00          nan
# Pokémon Collection                        20       50.14  250.72        66.87
# Godzilla (Showa) Collection               16        0.56    2.81          nan
# Charlie Chan (Warner Oland) Collection    15         nan    0.00          nan
# Dragon Ball Z (Movie) Collection          15        5.00    5.00        56.06
# Uuno Turhapuro                            15         nan    0.00          nan
# Monster High Collection                   14        0.50    0.50          nan
# The Land Before Time Collection           14       12.30   12.30        84.46
# George Carlin Comedy Collection           13         nan    0.00          nan
# Sharpe Collection                         13         nan    0.00          nan
# Friday the 13th Collection                12        7.03   84.40        38.74
# Johan Falk GSI Collection                 12         nan    0.00          nan
# Sherlock Holmes (1939 series)             12         nan    0.00          nan
# The Amityville Horror Collection          12        5.25   21.02        53.34
# An American Girl Collection               10        6.80    6.80          nan
#
#                                                vote_average popularity    ROI  \
#                                            sum         mean       mean median
# belongs_to_collection
# The Bowery Boys                           0.00         6.67       0.20    nan
# Totò Collection                           0.00         6.84       1.05    nan
# James Bond Collection                  7106.97         6.34      13.45   6.13
# Zatôichi: The Blind Swordsman             0.00         6.40       1.10    nan
# The Carry On Collection                   0.00         6.17       3.22    nan
# Charlie Chan (Sidney Toler) Collection    0.00         6.61       0.63    nan
# Pokémon Collection                      601.87         6.06       4.37   4.46
# Godzilla (Showa) Collection               0.00         5.98       3.42    nan
# Charlie Chan (Warner Oland) Collection    0.00         6.66       0.66    nan
# Dragon Ball Z (Movie) Collection        112.12         6.61       6.18  12.35
# Uuno Turhapuro                            0.00         5.53       0.17    nan
# Monster High Collection                   0.00         6.49       3.59    nan
# The Land Before Time Collection          84.46         6.16       4.91   6.87
# George Carlin Comedy Collection           0.00         7.47       1.30    nan
# Sharpe Collection                         0.00         6.74       1.71    nan
# Friday the 13th Collection              464.90         5.42       9.76   6.67
# Johan Falk GSI Collection                 0.00         6.50       1.52    nan
# Sherlock Holmes (1939 series)             0.00         6.92       2.88    nan
# The Amityville Horror Collection        213.35         4.36       7.18   5.69
# An American Girl Collection               0.00         5.25       1.94    nan
#
#                                        vote_count
#                                              mean
# belongs_to_collection
# The Bowery Boys                              0.72
# Totò Collection                             18.04
# James Bond Collection                     1284.31
# Zatôichi: The Blind Swordsman               11.19
# The Carry On Collection                     21.04
# Charlie Chan (Sidney Toler) Collection       5.81
# Pokémon Collection                          71.10
# Godzilla (Showa) Collection                 39.75
# Charlie Chan (Warner Oland) Collection       6.87
# Dragon Ball Z (Movie) Collection           133.33
# Uuno Turhapuro                               3.87
# Monster High Collection                     12.57
# The Land Before Time Collection             96.07
# George Carlin Comedy Collection             12.54
# Sharpe Collection                           13.23
# Friday the 13th Collection                 326.58
# Johan Falk GSI Collection                    9.25
# Sherlock Holmes (1939 series)               21.58
# The Amityville Horror Collection            91.92
# An American Girl Collection                  8.70

# %%
franchise.nlargest(20, ('revenue_musd','sum'))
# Out:
#                                     title budget_musd         revenue_musd  \
#                                     count        mean     sum         mean
# belongs_to_collection
# Harry Potter Collection                 8      160.00 1280.00       963.42
# Star Wars Collection                    8      106.79  854.35       929.31
# James Bond Collection                  26       59.22 1539.65       273.35
# The Fast and the Furious Collection     8      126.12 1009.00       640.64
# Pirates of the Caribbean Collection     5      250.00 1250.00       904.32
# Transformers Collection                 5      193.00  965.00       873.22
# Despicable Me Collection                6       74.75  299.00       922.77
# The Twilight Collection                 5       77.00  385.00       668.42
# Ice Age Collection                      5       85.80  429.00       643.34
# Jurassic Park Collection                4       94.75  379.00       757.87
# Shrek Collection                        5      133.75  535.00       738.95
# The Hunger Games Collection             4      122.50  490.00       736.04
# The Hobbit Collection                   3      250.00  750.00       978.51
# The Avengers Collection                 2      250.00  500.00      1462.48
# The Lord of the Rings Collection        3       88.67  266.00       972.18
# X-Men Collection                        6      163.83  983.00       468.14
# Avatar Collection                       1      237.00  237.00      2787.97
# Mission: Impossible Collection          5      130.00  650.00       555.80
# Spider-Man Collection                   3      199.00  597.00       832.12
# The Dark Knight Collection              3      195.00  585.00       821.24
#
#                                             vote_average popularity    ROI  \
#                                         sum         mean       mean median
# belongs_to_collection
# Harry Potter Collection             7707.37         7.54      26.25   6.17
# Star Wars Collection                7434.49         7.37      23.41   8.24
# James Bond Collection               7106.97         6.34      13.45   6.13
# The Fast and the Furious Collection 5125.10         6.66      10.80   4.94
# Pirates of the Caribbean Collection 4521.58         6.88      53.97   3.45
# Transformers Collection             4366.10         6.14      14.43   5.20
# Despicable Me Collection            3691.07         6.78     106.72  12.76
# The Twilight Collection             3342.11         5.84      29.50  10.27
# Ice Age Collection                  3216.71         6.38      16.08   8.26
# Jurassic Park Collection            3031.48         6.50      10.77   7.03
# Shrek Collection                    2955.81         6.46      12.97   5.56
# The Hunger Games Collection         2944.16         6.88      54.77   6.27
# The Hobbit Collection               2935.52         7.23      25.21   3.83
# The Avengers Collection             2924.96         7.35      63.63   5.96
# The Lord of the Rings Collection    2916.54         8.03      30.27  11.73
# X-Men Collection                    2808.83         6.82       9.71   3.02
# Avatar Collection                   2787.97         7.20     185.07  11.76
# Mission: Impossible Collection      2778.98         6.60      16.51   4.55
# Spider-Man Collection               2496.35         6.47      22.62   3.92
# The Dark Knight Collection          2463.72         7.80      57.42   4.34
#
#                                     vote_count
#                                           mean
# belongs_to_collection
# Harry Potter Collection                5983.25
# Star Wars Collection                   5430.38
# James Bond Collection                  1284.31
# The Fast and the Furious Collection    3197.00
# Pirates of the Caribbean Collection    5016.00
# Transformers Collection                3046.40
# Despicable Me Collection               3041.33
# The Twilight Collection                2770.20
# Ice Age Collection                     2643.80
# Jurassic Park Collection               4608.75
# Shrek Collection                       2344.20
# The Hunger Games Collection            6543.50
# The Hobbit Collection                  5981.33
# The Avengers Collection                9454.00
# The Lord of the Rings Collection       8253.00
# X-Men Collection                       4593.83
# Avatar Collection                     12114.00
# Mission: Impossible Collection         2801.00
# Spider-Man Collection                  4505.67
# The Dark Knight Collection             9681.00

# %%
franchise.nlargest(20, ('budget_musd','sum'))
# Out:
#                                         title budget_musd          \
#                                         count        mean     sum
# belongs_to_collection
# James Bond Collection                      26       59.22 1539.65
# Harry Potter Collection                     8      160.00 1280.00
# Pirates of the Caribbean Collection         5      250.00 1250.00
# The Fast and the Furious Collection         8      126.12 1009.00
# X-Men Collection                            6      163.83  983.00
# Transformers Collection                     5      193.00  965.00
# Star Wars Collection                        8      106.79  854.35
# The Hobbit Collection                       3      250.00  750.00
# The Terminator Collection                   5      132.28  661.40
# Mission: Impossible Collection              5      130.00  650.00
# Spider-Man Collection                       3      199.00  597.00
# The Dark Knight Collection                  3      195.00  585.00
# Captain America Collection                  3      186.67  560.00
# The Chronicles of Narnia Collection         3      186.67  560.00
# Iron Man Collection                         3      180.00  540.00
# Shrek Collection                            5      133.75  535.00
# Star Trek: Alternate Reality Collection     3      175.00  525.00
# Madagascar Collection                       4      125.50  502.00
# The Avengers Collection                     2      250.00  500.00
# Cars Collection                             3      165.00  495.00
#
#                                         revenue_musd         vote_average  \
#                                                 mean     sum         mean
# belongs_to_collection
# James Bond Collection                         273.35 7106.97         6.34
# Harry Potter Collection                       963.42 7707.37         7.54
# Pirates of the Caribbean Collection           904.32 4521.58         6.88
# The Fast and the Furious Collection           640.64 5125.10         6.66
# X-Men Collection                              468.14 2808.83         6.82
# Transformers Collection                       873.22 4366.10         6.14
# Star Wars Collection                          929.31 7434.49         7.37
# The Hobbit Collection                         978.51 2935.52         7.23
# The Terminator Collection                     369.07 1845.33         6.54
# Mission: Impossible Collection                555.80 2778.98         6.60
# Spider-Man Collection                         832.12 2496.35         6.47
# The Dark Knight Collection                    821.24 2463.72         7.80
# Captain America Collection                    746.21 2238.64         7.10
# The Chronicles of Narnia Collection           528.05 1584.14         6.40
# Iron Man Collection                           808.18 2424.55         6.93
# Shrek Collection                              738.95 2955.81         6.46
# Star Trek: Alternate Reality Collection       398.84 1196.52         7.13
# Madagascar Collection                         564.26 2257.05         6.43
# The Avengers Collection                      1462.48 2924.96         7.35
# Cars Collection                               457.34 1372.01         6.33
#
#                                         popularity    ROI vote_count
#                                               mean median       mean
# belongs_to_collection
# James Bond Collection                        13.45   6.13    1284.31
# Harry Potter Collection                      26.25   6.17    5983.25
# Pirates of the Caribbean Collection          53.97   3.45    5016.00
# The Fast and the Furious Collection          10.80   4.94    3197.00
# X-Men Collection                              9.71   3.02    4593.83
# Transformers Collection                      14.43   5.20    3046.40
# Star Wars Collection                         23.41   8.24    5430.38
# The Hobbit Collection                        25.21   3.83    5981.33
# The Terminator Collection                    21.89   2.84    3366.40
# Mission: Impossible Collection               16.51   4.55    2801.00
# Spider-Man Collection                        22.62   3.92    4505.67
# The Dark Knight Collection                   57.42   4.34    9681.00
# Captain America Collection                   61.31   4.20    6839.00
# The Chronicles of Narnia Collection          14.34   2.68    1977.33
# Iron Man Collection                          21.63   4.18    8290.33
# Shrek Collection                             12.97   5.56    2344.20
# Star Trek: Alternate Reality Collection      17.27   2.46    3896.33
# Madagascar Collection                        16.21   4.59    2105.00
# The Avengers Collection                      63.63   5.96    9454.00
# Cars Collection                              17.25   2.80    2265.67

# %%
franchise.nlargest(20, ('budget_musd','mean'))
# Out:
#                                         title budget_musd          \
#                                         count        mean     sum
# belongs_to_collection
# Tangled Collection                          2      260.00  260.00
# Pirates of the Caribbean Collection         5      250.00 1250.00
# The Avengers Collection                     2      250.00  500.00
# The Hobbit Collection                       3      250.00  750.00
# Man of Steel Collection                     2      237.50  475.00
# Avatar Collection                           1      237.00  237.00
# The Amazing Spider-Man Collection           2      207.50  415.00
# World War Z Collection                      1      200.00  200.00
# Spider-Man Collection                       3      199.00  597.00
# The Dark Knight Collection                  3      195.00  585.00
# Transformers Collection                     5      193.00  965.00
# Captain America Collection                  3      186.67  560.00
# The Chronicles of Narnia Collection         3      186.67  560.00
# Alice in Wonderland Collection              2      185.00  370.00
# Guardians of the Galaxy Collection          2      185.00  370.00
# Fantastic Beasts Collection                 1      180.00  180.00
# Iron Man Collection                         3      180.00  540.00
# Pacific Rim Collection                      1      180.00  180.00
# Star Trek: Alternate Reality Collection     3      175.00  525.00
# Cars Collection                             3      165.00  495.00
#
#                                         revenue_musd         vote_average  \
#                                                 mean     sum         mean
# belongs_to_collection
# Tangled Collection                            591.79  591.79         7.25
# Pirates of the Caribbean Collection           904.32 4521.58         6.88
# The Avengers Collection                      1462.48 2924.96         7.35
# The Hobbit Collection                         978.51 2935.52         7.23
# Man of Steel Collection                       768.05 1536.11         6.10
# Avatar Collection                            2787.97 2787.97         7.20
# The Amazing Spider-Man Collection             728.97 1457.93         6.50
# World War Z Collection                        531.87  531.87         6.70
# Spider-Man Collection                         832.12 2496.35         6.47
# The Dark Knight Collection                    821.24 2463.72         7.80
# Transformers Collection                       873.22 4366.10         6.14
# Captain America Collection                    746.21 2238.64         7.10
# The Chronicles of Narnia Collection           528.05 1584.14         6.40
# Alice in Wonderland Collection                662.43 1324.86         6.45
# Guardians of the Galaxy Collection            818.37 1636.74         7.75
# Fantastic Beasts Collection                   809.34  809.34         7.20
# Iron Man Collection                           808.18 2424.55         6.93
# Pacific Rim Collection                        407.60  407.60         6.70
# Star Trek: Alternate Reality Collection       398.84 1196.52         7.13
# Cars Collection                               457.34 1372.01         6.33
#
#                                         popularity    ROI vote_count
#                                               mean median       mean
# belongs_to_collection
# Tangled Collection                           12.32   2.28    1901.00
# Pirates of the Caribbean Collection          53.97   3.45    5016.00
# The Avengers Collection                      63.63   5.96    9454.00
# The Hobbit Collection                        25.21   3.83    5981.33
# Man of Steel Collection                      24.99   3.22    6825.50
# Avatar Collection                           185.07  11.76   12114.00
# The Amazing Spider-Man Collection            28.67   3.51    5504.00
# World War Z Collection                       26.11   2.66    5683.00
# Spider-Man Collection                        22.62   3.92    4505.67
# The Dark Knight Collection                   57.42   4.34    9681.00
# Transformers Collection                      14.43   5.20    3046.40
# Captain America Collection                   61.31   4.20    6839.00
# The Chronicles of Narnia Collection          14.34   2.68    1977.33
# Alice in Wonderland Collection               15.95   3.44    3277.50
# Guardians of the Galaxy Collection          119.31   4.43    7436.00
# Fantastic Beasts Collection                  41.05   4.50    5612.00
# Iron Man Collection                          21.63   4.18    8290.33
# Pacific Rim Collection                       33.95   2.26    4903.00
# Star Trek: Alternate Reality Collection      17.27   2.46    3896.33
# Cars Collection                              17.25   2.80    2265.67

# %%
franchise.nlargest(20, ('vote_count','mean'))
# Out:
#                                    title budget_musd         revenue_musd  \
#                                    count        mean     sum         mean
# belongs_to_collection
# Avatar Collection                      1      237.00  237.00      2787.97
# Deadpool Collection                    1       58.00   58.00       783.11
# The Dark Knight Collection             3      195.00  585.00       821.24
# The Avengers Collection                2      250.00  500.00      1462.48
# Iron Man Collection                    3      180.00  540.00       808.18
# The Lord of the Rings Collection       3       88.67  266.00       972.18
# Guardians of the Galaxy Collection     2      185.00  370.00       818.37
# Captain America Collection             3      186.67  560.00       746.21
# Man of Steel Collection                2      237.50  475.00       768.05
# The Hunger Games Collection            4      122.50  490.00       736.04
# Kingsman Collection                    1       81.00   81.00       414.35
# Ant-Man Collection                     1      130.00  130.00       519.31
# Harry Potter Collection                8      160.00 1280.00       963.42
# The Hobbit Collection                  3      250.00  750.00       978.51
# Thor Collection                        2      160.00  320.00       546.95
# World War Z Collection                 1      200.00  200.00       531.87
# Fantastic Beasts Collection            1      180.00  180.00       809.34
# The Amazing Spider-Man Collection      2      207.50  415.00       728.97
# Star Wars Collection                   8      106.79  854.35       929.31
# Finding Nemo Collection                2      147.00  294.00       984.45
#
#                                            vote_average popularity    ROI  \
#                                        sum         mean       mean median
# belongs_to_collection
# Avatar Collection                  2787.97         7.20     185.07  11.76
# Deadpool Collection                 783.11         7.40     187.86  13.50
# The Dark Knight Collection         2463.72         7.80      57.42   4.34
# The Avengers Collection            2924.96         7.35      63.63   5.96
# Iron Man Collection                2424.55         6.93      21.63   4.18
# The Lord of the Rings Collection   2916.54         8.03      30.27  11.73
# Guardians of the Galaxy Collection 1636.74         7.75     119.31   4.43
# Captain America Collection         2238.64         7.10      61.31   4.20
# Man of Steel Collection            1536.11         6.10      24.99   3.22
# The Hunger Games Collection        2944.16         6.88      54.77   6.27
# Kingsman Collection                 414.35         7.60      28.22   5.12
# Ant-Man Collection                  519.31         7.00      26.88   3.99
# Harry Potter Collection            7707.37         7.54      26.25   6.17
# The Hobbit Collection              2935.52         7.23      25.21   3.83
# Thor Collection                    1093.90         6.70      32.03   3.39
# World War Z Collection              531.87         6.70      26.11   2.66
# Fantastic Beasts Collection         809.34         7.20      41.05   4.50
# The Amazing Spider-Man Collection  1457.93         6.50      28.67   3.51
# Star Wars Collection               7434.49         7.37      23.41   8.24
# Finding Nemo Collection            1968.91         7.20      19.99   7.57
#
#                                    vote_count
#                                          mean
# belongs_to_collection
# Avatar Collection                    12114.00
# Deadpool Collection                  11444.00
# The Dark Knight Collection            9681.00
# The Avengers Collection               9454.00
# Iron Man Collection                   8290.33
# The Lord of the Rings Collection      8253.00
# Guardians of the Galaxy Collection    7436.00
# Captain America Collection            6839.00
# Man of Steel Collection               6825.50
# The Hunger Games Collection           6543.50
# Kingsman Collection                   6069.00
# Ant-Man Collection                    6029.00
# Harry Potter Collection               5983.25
# The Hobbit Collection                 5981.33
# Thor Collection                       5775.50
# World War Z Collection                5683.00
# Fantastic Beasts Collection           5612.00
# The Amazing Spider-Man Collection     5504.00
# Star Wars Collection                  5430.38
# Finding Nemo Collection               5312.50

# %% [markdown]
# **Most Sucessful Directors**

# %%
dir = df.groupby('director').revenue_musd.sum().nlargest(20)

# %%
plt.figure(figsize=(12,8))
dir.plot(kind='bar', fontsize=15)
plt.title('total revenue', fontsize=20)
plt.ylabel('Renevue in MUSD', fontsize=15)
plt.show()

# %%
dir = df.groupby('director').agg({'title':'count', 
                             'vote_average':'mean',
                             'vote_count':'sum'})

# %%
dir
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %%
dir[(dir.vote_count >=10000) & (dir.title >10)].nlargest(20,'vote_average')
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# Ang Lee               14          6.71    11164.00
# Antoine Fuqua         12          6.71    15519.00
# Woody Allen           49          6.69    15512.00
# Clint Eastwood        35          6.69    24001.00
# Alfred Hitchcock      53          6.64    12772.00
# Ridley Scott          24          6.60    43083.00
# Kenneth Branagh       14          6.59    11275.00
# Luc Besson            16          6.52    19627.00

# %%
#most successful horror director
df.genres = df.genres.astype(str)
df.loc[df.genres.str.contains('Horror')].groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64
